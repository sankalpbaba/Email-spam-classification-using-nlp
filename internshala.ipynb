# %% [markdown]
# The dataset i used for the below naive bayes spam classification is taken from kaggle.It was difficult to preprocess the given dataset into phishing and non phishing emails.

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import words
import pandas as pd
import numpy as np
import ast

# %%
vocabulary = {}
data = pd.read_csv("data/emails.csv")
nltk.download("words")
set_words = set(words.words())


def build_vocabulary(curr_email):
    idx = len(vocabulary)
    for word in curr_email:
        if word.lower() not in vocabulary and word.lower() in set_words:
            vocabulary[word] = idx
            idx += 1


if __name__ == "__main__":
    for i in range(data.shape[0]):
        curr_email = data.iloc[i, :][0].split()
        print(
            f"Current email is {i}/{data.shape[0]} and the \
               length of vocab is curr {len(vocabulary)}"
        )

        build_vocabulary(curr_email)

# Write dictionary to vocabulary.txt file
file = open("vocabulary.txt", "w")
file.write(str(vocabulary))
file.close()
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\sanka\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Current email is 0/5728 and the                length of vocab is curr 0
# Current email is 1/5728 and the                length of vocab is curr 102
# Current email is 2/5728 and the                length of vocab is curr 142
# Current email is 3/5728 and the                length of vocab is curr 173
# Current email is 4/5728 and the                length of vocab is curr 194
# Current email is 5/5728 and the                length of vocab is curr 210
# Current email is 6/5728 and the                length of vocab is curr 242
# Current email is 7/5728 and the                length of vocab is curr 559
# Current email is 8/5728 and the                length of vocab is curr 576
# Current email is 9/5728 and the                length of vocab is curr 593
# Current email is 10/5728 and the                length of vocab is curr 593
# Current email is 11/5728 and the                length of vocab is curr 624
# Current email is 12/5728 and the                length of vocab is curr 625
# Current email is 13/5728 and the                length of vocab is curr 654
# Current email is 14/5728 and the                length of vocab is curr 778
# Current email is 15/5728 and the                length of vocab is curr 799
# Current email is 16/5728 and the                length of vocab is curr 830
# Current email is 17/5728 and the                length of vocab is curr 840
# Current email is 18/5728 and the                length of vocab is curr 851
# Current email is 19/5728 and the                length of vocab is curr 855
# Current email is 20/5728 and the                length of vocab is curr 920
# Current email is 21/5728 and the                length of vocab is curr 932
# Current email is 22/5728 and the                length of vocab is curr 953
# Current email is 23/5728 and the                length of vocab is curr 969
# Current email is 24/5728 and the                length of vocab is curr 982
# Current email is 25/5728 and the                length of vocab is curr 997
# Current email is 26/5728 and the                length of vocab is curr 1037
# Current email is 27/5728 and the                length of vocab is curr 1051
# Current email is 28/5728 and the                length of vocab is curr 1078
# Current email is 29/5728 and the                length of vocab is curr 1098
# Current email is 30/5728 and the                length of vocab is curr 1098
# Current email is 31/5728 and the                length of vocab is curr 1099
# Current email is 32/5728 and the                length of vocab is curr 1197
# Current email is 33/5728 and the                length of vocab is curr 1212
# Current email is 34/5728 and the                length of vocab is curr 1221
# Current email is 35/5728 and the                length of vocab is curr 1242
# Current email is 36/5728 and the                length of vocab is curr 1267
# Current email is 37/5728 and the                length of vocab is curr 1273
# Current email is 38/5728 and the                length of vocab is curr 1284
# Current email is 39/5728 and the                length of vocab is curr 1291
# Current email is 40/5728 and the                length of vocab is curr 1315
# Current email is 41/5728 and the                length of vocab is curr 1321
# Current email is 42/5728 and the                length of vocab is curr 1333
# Current email is 43/5728 and the                length of vocab is curr 1342
# Current email is 44/5728 and the                length of vocab is curr 1351
# Current email is 45/5728 and the                length of vocab is curr 1363
# Current email is 46/5728 and the                length of vocab is curr 1376
# Current email is 47/5728 and the                length of vocab is curr 1383
# Current email is 48/5728 and the                length of vocab is curr 1387
# Current email is 49/5728 and the                length of vocab is curr 1387
# Current email is 50/5728 and the                length of vocab is curr 1710
# Current email is 51/5728 and the                length of vocab is curr 1712
# Current email is 52/5728 and the                length of vocab is curr 1728
# Current email is 53/5728 and the                length of vocab is curr 1740
# Current email is 54/5728 and the                length of vocab is curr 1742
# Current email is 55/5728 and the                length of vocab is curr 1750
# Current email is 56/5728 and the                length of vocab is curr 1824
# Current email is 57/5728 and the                length of vocab is curr 1825
# Current email is 58/5728 and the                length of vocab is curr 1831
# Current email is 59/5728 and the                length of vocab is curr 1835
# Current email is 60/5728 and the                length of vocab is curr 1843
# Current email is 61/5728 and the                length of vocab is curr 1924
# Current email is 62/5728 and the                length of vocab is curr 1963
# Current email is 63/5728 and the                length of vocab is curr 1963
# Current email is 64/5728 and the                length of vocab is curr 1963
# Current email is 65/5728 and the                length of vocab is curr 1984
# Current email is 66/5728 and the                length of vocab is curr 1996
# Current email is 67/5728 and the                length of vocab is curr 2032
# Current email is 68/5728 and the                length of vocab is curr 2038
# Current email is 69/5728 and the                length of vocab is curr 2044
# Current email is 70/5728 and the                length of vocab is curr 2055
# Current email is 71/5728 and the                length of vocab is curr 2055
# Current email is 72/5728 and the                length of vocab is curr 2064
# Current email is 73/5728 and the                length of vocab is curr 2065
# Current email is 74/5728 and the                length of vocab is curr 2076
# Current email is 75/5728 and the                length of vocab is curr 2076
# Current email is 76/5728 and the                length of vocab is curr 2081
# Current email is 77/5728 and the                length of vocab is curr 2102
# Current email is 78/5728 and the                length of vocab is curr 2117
# Current email is 79/5728 and the                length of vocab is curr 2118
# Current email is 80/5728 and the                length of vocab is curr 2130
# Current email is 81/5728 and the                length of vocab is curr 2139
# Current email is 82/5728 and the                length of vocab is curr 2142
# Current email is 83/5728 and the                length of vocab is curr 2144
# Current email is 84/5728 and the                length of vocab is curr 2200
# Current email is 85/5728 and the                length of vocab is curr 2200
# Current email is 86/5728 and the                length of vocab is curr 2200
# Current email is 87/5728 and the                length of vocab is curr 2216
# Current email is 88/5728 and the                length of vocab is curr 2220
# Current email is 89/5728 and the                length of vocab is curr 2308
# Current email is 90/5728 and the                length of vocab is curr 2311
# Current email is 91/5728 and the                length of vocab is curr 2330
# Current email is 92/5728 and the                length of vocab is curr 2334
# Current email is 93/5728 and the                length of vocab is curr 2347
# Current email is 94/5728 and the                length of vocab is curr 2376
# Current email is 95/5728 and the                length of vocab is curr 2382
# Current email is 96/5728 and the                length of vocab is curr 2399
# Current email is 97/5728 and the                length of vocab is curr 2403
# Current email is 98/5728 and the                length of vocab is curr 2416
# Current email is 99/5728 and the                length of vocab is curr 2418
# Current email is 100/5728 and the                length of vocab is curr 2418
# Current email is 101/5728 and the                length of vocab is curr 2425
# Current email is 102/5728 and the                length of vocab is curr 2436
# Current email is 103/5728 and the                length of vocab is curr 2458
# Current email is 104/5728 and the                length of vocab is curr 2466
# Current email is 105/5728 and the                length of vocab is curr 2466
# Current email is 106/5728 and the                length of vocab is curr 2473
# Current email is 107/5728 and the                length of vocab is curr 2493
# Current email is 108/5728 and the                length of vocab is curr 2497
# Current email is 109/5728 and the                length of vocab is curr 2497
# Current email is 110/5728 and the                length of vocab is curr 2502
# Current email is 111/5728 and the                length of vocab is curr 2521
# Current email is 112/5728 and the                length of vocab is curr 2526
# Current email is 113/5728 and the                length of vocab is curr 2530
# Current email is 114/5728 and the                length of vocab is curr 2535
# Current email is 115/5728 and the                length of vocab is curr 2540
# Current email is 116/5728 and the                length of vocab is curr 2541
# Current email is 117/5728 and the                length of vocab is curr 2573
# Current email is 118/5728 and the                length of vocab is curr 2573
# Current email is 119/5728 and the                length of vocab is curr 2578
# Current email is 120/5728 and the                length of vocab is curr 2580
# Current email is 121/5728 and the                length of vocab is curr 2580
# Current email is 122/5728 and the                length of vocab is curr 2589
# Current email is 123/5728 and the                length of vocab is curr 2591
# Current email is 124/5728 and the                length of vocab is curr 2607
# Current email is 125/5728 and the                length of vocab is curr 2617
# Current email is 126/5728 and the                length of vocab is curr 2632
# Current email is 127/5728 and the                length of vocab is curr 2788
# Current email is 128/5728 and the                length of vocab is curr 2806
# Current email is 129/5728 and the                length of vocab is curr 2806
# Current email is 130/5728 and the                length of vocab is curr 2842
# Current email is 131/5728 and the                length of vocab is curr 2845
# Current email is 132/5728 and the                length of vocab is curr 2866
# Current email is 133/5728 and the                length of vocab is curr 2868
# Current email is 134/5728 and the                length of vocab is curr 2876
# Current email is 135/5728 and the                length of vocab is curr 2876
# Current email is 136/5728 and the                length of vocab is curr 2884
# Current email is 137/5728 and the                length of vocab is curr 2885
# Current email is 138/5728 and the                length of vocab is curr 2885
# Current email is 139/5728 and the                length of vocab is curr 2896
# Current email is 140/5728 and the                length of vocab is curr 2898
# Current email is 141/5728 and the                length of vocab is curr 2898
# Current email is 142/5728 and the                length of vocab is curr 2898
# Current email is 143/5728 and the                length of vocab is curr 2916
# Current email is 144/5728 and the                length of vocab is curr 2918
# Current email is 145/5728 and the                length of vocab is curr 2918
# Current email is 146/5728 and the                length of vocab is curr 2923
# Current email is 147/5728 and the                length of vocab is curr 2924
# Current email is 148/5728 and the                length of vocab is curr 2927
# Current email is 149/5728 and the                length of vocab is curr 2927
# Current email is 150/5728 and the                length of vocab is curr 2943
# Current email is 151/5728 and the                length of vocab is curr 2966
# Current email is 152/5728 and the                length of vocab is curr 3100
# Current email is 153/5728 and the                length of vocab is curr 3118
# Current email is 154/5728 and the                length of vocab is curr 3118
# Current email is 155/5728 and the                length of vocab is curr 3123
# Current email is 156/5728 and the                length of vocab is curr 3123
# Current email is 157/5728 and the                length of vocab is curr 3135
# Current email is 158/5728 and the                length of vocab is curr 3141
# Current email is 159/5728 and the                length of vocab is curr 3161
# Current email is 160/5728 and the                length of vocab is curr 3177
# Current email is 161/5728 and the                length of vocab is curr 3177
# Current email is 162/5728 and the                length of vocab is curr 3177
# Current email is 163/5728 and the                length of vocab is curr 3178
# Current email is 164/5728 and the                length of vocab is curr 3178
# Current email is 165/5728 and the                length of vocab is curr 3179
# Current email is 166/5728 and the                length of vocab is curr 3180
# Current email is 167/5728 and the                length of vocab is curr 3181
# Current email is 168/5728 and the                length of vocab is curr 3181
# Current email is 169/5728 and the                length of vocab is curr 3185
# Current email is 170/5728 and the                length of vocab is curr 3297
# Current email is 171/5728 and the                length of vocab is curr 3299
# Current email is 172/5728 and the                length of vocab is curr 3299
# Current email is 173/5728 and the                length of vocab is curr 3303
# Current email is 174/5728 and the                length of vocab is curr 3304
# Current email is 175/5728 and the                length of vocab is curr 3306
# Current email is 176/5728 and the                length of vocab is curr 3313
# Current email is 177/5728 and the                length of vocab is curr 3330
# Current email is 178/5728 and the                length of vocab is curr 3340
# Current email is 179/5728 and the                length of vocab is curr 3340
# Current email is 180/5728 and the                length of vocab is curr 3384
# Current email is 181/5728 and the                length of vocab is curr 3388
# Current email is 182/5728 and the                length of vocab is curr 3400
# Current email is 183/5728 and the                length of vocab is curr 3405
# Current email is 184/5728 and the                length of vocab is curr 3409
# Current email is 185/5728 and the                length of vocab is curr 3413
# Current email is 186/5728 and the                length of vocab is curr 3452
# Current email is 187/5728 and the                length of vocab is curr 3454
# Current email is 188/5728 and the                length of vocab is curr 3459
# Current email is 189/5728 and the                length of vocab is curr 3468
# Current email is 190/5728 and the                length of vocab is curr 3468
# Current email is 191/5728 and the                length of vocab is curr 3473
# Current email is 192/5728 and the                length of vocab is curr 3477
# Current email is 193/5728 and the                length of vocab is curr 3559
# Current email is 194/5728 and the                length of vocab is curr 3559
# Current email is 195/5728 and the                length of vocab is curr 3566
# Current email is 196/5728 and the                length of vocab is curr 3566
# Current email is 197/5728 and the                length of vocab is curr 3566
# Current email is 198/5728 and the                length of vocab is curr 3593
# Current email is 199/5728 and the                length of vocab is curr 3593
# Current email is 200/5728 and the                length of vocab is curr 3597
# Current email is 201/5728 and the                length of vocab is curr 3598
# Current email is 202/5728 and the                length of vocab is curr 3602
# Current email is 203/5728 and the                length of vocab is curr 3602
# Current email is 204/5728 and the                length of vocab is curr 3609
# Current email is 205/5728 and the                length of vocab is curr 3609
# Current email is 206/5728 and the                length of vocab is curr 3624
# Current email is 207/5728 and the                length of vocab is curr 3638
# Current email is 208/5728 and the                length of vocab is curr 3638
# Current email is 209/5728 and the                length of vocab is curr 3655
# Current email is 210/5728 and the                length of vocab is curr 3658
# Current email is 211/5728 and the                length of vocab is curr 3662
# Current email is 212/5728 and the                length of vocab is curr 3662
# Current email is 213/5728 and the                length of vocab is curr 3662
# Current email is 214/5728 and the                length of vocab is curr 3700
# Current email is 215/5728 and the                length of vocab is curr 3712
# Current email is 216/5728 and the                length of vocab is curr 3712
# Current email is 217/5728 and the                length of vocab is curr 3713
# Current email is 218/5728 and the                length of vocab is curr 3715
# Current email is 219/5728 and the                length of vocab is curr 3717
# Current email is 220/5728 and the                length of vocab is curr 3717
# Current email is 221/5728 and the                length of vocab is curr 3717
# Current email is 222/5728 and the                length of vocab is curr 3721
# Current email is 223/5728 and the                length of vocab is curr 3727
# Current email is 224/5728 and the                length of vocab is curr 3728
# Current email is 225/5728 and the                length of vocab is curr 3737
# Current email is 226/5728 and the                length of vocab is curr 3737
# Current email is 227/5728 and the                length of vocab is curr 3741
# Current email is 228/5728 and the                length of vocab is curr 3752
# Current email is 229/5728 and the                length of vocab is curr 3764
# Current email is 230/5728 and the                length of vocab is curr 3764
# Current email is 231/5728 and the                length of vocab is curr 3768
# Current email is 232/5728 and the                length of vocab is curr 3773
# Current email is 233/5728 and the                length of vocab is curr 3781
# Current email is 234/5728 and the                length of vocab is curr 3781
# Current email is 235/5728 and the                length of vocab is curr 3783
# Current email is 236/5728 and the                length of vocab is curr 3787
# Current email is 237/5728 and the                length of vocab is curr 3790
# Current email is 238/5728 and the                length of vocab is curr 3791
# Current email is 239/5728 and the                length of vocab is curr 3792
# Current email is 240/5728 and the                length of vocab is curr 3794
# Current email is 241/5728 and the                length of vocab is curr 3807
# Current email is 242/5728 and the                length of vocab is curr 3810
# Current email is 243/5728 and the                length of vocab is curr 3810
# Current email is 244/5728 and the                length of vocab is curr 3815
# Current email is 245/5728 and the                length of vocab is curr 3819
# Current email is 246/5728 and the                length of vocab is curr 3822
# Current email is 247/5728 and the                length of vocab is curr 3822
# Current email is 248/5728 and the                length of vocab is curr 3826
# Current email is 249/5728 and the                length of vocab is curr 3827
# Current email is 250/5728 and the                length of vocab is curr 3829
# Current email is 251/5728 and the                length of vocab is curr 3830
# Current email is 252/5728 and the                length of vocab is curr 3834
# Current email is 253/5728 and the                length of vocab is curr 3836
# Current email is 254/5728 and the                length of vocab is curr 3836
# Current email is 255/5728 and the                length of vocab is curr 3850
# Current email is 256/5728 and the                length of vocab is curr 3850
# Current email is 257/5728 and the                length of vocab is curr 3850
# Current email is 258/5728 and the                length of vocab is curr 3850
# Current email is 259/5728 and the                length of vocab is curr 3851
# Current email is 260/5728 and the                length of vocab is curr 3857
# Current email is 261/5728 and the                length of vocab is curr 3861
# Current email is 262/5728 and the                length of vocab is curr 3866
# Current email is 263/5728 and the                length of vocab is curr 3866
# Current email is 264/5728 and the                length of vocab is curr 3880
# Current email is 265/5728 and the                length of vocab is curr 3882
# Current email is 266/5728 and the                length of vocab is curr 3882
# Current email is 267/5728 and the                length of vocab is curr 3898
# Current email is 268/5728 and the                length of vocab is curr 3898
# Current email is 269/5728 and the                length of vocab is curr 3903
# Current email is 270/5728 and the                length of vocab is curr 3924
# Current email is 271/5728 and the                length of vocab is curr 3925
# Current email is 272/5728 and the                length of vocab is curr 3926
# Current email is 273/5728 and the                length of vocab is curr 3934
# Current email is 274/5728 and the                length of vocab is curr 3935
# Current email is 275/5728 and the                length of vocab is curr 3950
# Current email is 276/5728 and the                length of vocab is curr 3956
# Current email is 277/5728 and the                length of vocab is curr 3961
# Current email is 278/5728 and the                length of vocab is curr 3961
# Current email is 279/5728 and the                length of vocab is curr 3981
# Current email is 280/5728 and the                length of vocab is curr 3987
# Current email is 281/5728 and the                length of vocab is curr 3988
# Current email is 282/5728 and the                length of vocab is curr 4001
# Current email is 283/5728 and the                length of vocab is curr 4002
# Current email is 284/5728 and the                length of vocab is curr 4009
# Current email is 285/5728 and the                length of vocab is curr 4013
# Current email is 286/5728 and the                length of vocab is curr 4013
# Current email is 287/5728 and the                length of vocab is curr 4014
# Current email is 288/5728 and the                length of vocab is curr 4014
# Current email is 289/5728 and the                length of vocab is curr 4014
# Current email is 290/5728 and the                length of vocab is curr 4014
# Current email is 291/5728 and the                length of vocab is curr 4014
# Current email is 292/5728 and the                length of vocab is curr 4017
# Current email is 293/5728 and the                length of vocab is curr 4021
# Current email is 294/5728 and the                length of vocab is curr 4021
# Current email is 295/5728 and the                length of vocab is curr 4048
# Current email is 296/5728 and the                length of vocab is curr 4064
# Current email is 297/5728 and the                length of vocab is curr 4064
# Current email is 298/5728 and the                length of vocab is curr 4068
# Current email is 299/5728 and the                length of vocab is curr 4069
# Current email is 300/5728 and the                length of vocab is curr 4080
# Current email is 301/5728 and the                length of vocab is curr 4089
# Current email is 302/5728 and the                length of vocab is curr 4094
# Current email is 303/5728 and the                length of vocab is curr 4111
# Current email is 304/5728 and the                length of vocab is curr 4111
# Current email is 305/5728 and the                length of vocab is curr 4116
# Current email is 306/5728 and the                length of vocab is curr 4116
# Current email is 307/5728 and the                length of vocab is curr 4117
# Current email is 308/5728 and the                length of vocab is curr 4117
# Current email is 309/5728 and the                length of vocab is curr 4117
# Current email is 310/5728 and the                length of vocab is curr 4119
# Current email is 311/5728 and the                length of vocab is curr 4131
# Current email is 312/5728 and the                length of vocab is curr 4135
# Current email is 313/5728 and the                length of vocab is curr 4148
# Current email is 314/5728 and the                length of vocab is curr 4148
# Current email is 315/5728 and the                length of vocab is curr 4157
# Current email is 316/5728 and the                length of vocab is curr 4159
# Current email is 317/5728 and the                length of vocab is curr 4160
# Current email is 318/5728 and the                length of vocab is curr 4171
# Current email is 319/5728 and the                length of vocab is curr 4171
# Current email is 320/5728 and the                length of vocab is curr 4171
# Current email is 321/5728 and the                length of vocab is curr 4174
# Current email is 322/5728 and the                length of vocab is curr 4180
# Current email is 323/5728 and the                length of vocab is curr 4197
# Current email is 324/5728 and the                length of vocab is curr 4202
# Current email is 325/5728 and the                length of vocab is curr 4204
# Current email is 326/5728 and the                length of vocab is curr 4204
# Current email is 327/5728 and the                length of vocab is curr 4216
# Current email is 328/5728 and the                length of vocab is curr 4223
# Current email is 329/5728 and the                length of vocab is curr 4223
# Current email is 330/5728 and the                length of vocab is curr 4232
# Current email is 331/5728 and the                length of vocab is curr 4234
# Current email is 332/5728 and the                length of vocab is curr 4250
# Current email is 333/5728 and the                length of vocab is curr 4256
# Current email is 334/5728 and the                length of vocab is curr 4259
# Current email is 335/5728 and the                length of vocab is curr 4260
# Current email is 336/5728 and the                length of vocab is curr 4263
# Current email is 337/5728 and the                length of vocab is curr 4280
# Current email is 338/5728 and the                length of vocab is curr 4283
# Current email is 339/5728 and the                length of vocab is curr 4283
# Current email is 340/5728 and the                length of vocab is curr 4283
# Current email is 341/5728 and the                length of vocab is curr 4287
# Current email is 342/5728 and the                length of vocab is curr 4296
# Current email is 343/5728 and the                length of vocab is curr 4296
# Current email is 344/5728 and the                length of vocab is curr 4296
# Current email is 345/5728 and the                length of vocab is curr 4297
# Current email is 346/5728 and the                length of vocab is curr 4297
# Current email is 347/5728 and the                length of vocab is curr 4298
# Current email is 348/5728 and the                length of vocab is curr 4303
# Current email is 349/5728 and the                length of vocab is curr 4303
# Current email is 350/5728 and the                length of vocab is curr 4333
# Current email is 351/5728 and the                length of vocab is curr 4336
# Current email is 352/5728 and the                length of vocab is curr 4336
# Current email is 353/5728 and the                length of vocab is curr 4338
# Current email is 354/5728 and the                length of vocab is curr 4338
# Current email is 355/5728 and the                length of vocab is curr 4338
# Current email is 356/5728 and the                length of vocab is curr 4338
# Current email is 357/5728 and the                length of vocab is curr 4338
# Current email is 358/5728 and the                length of vocab is curr 4338
# Current email is 359/5728 and the                length of vocab is curr 4338
# Current email is 360/5728 and the                length of vocab is curr 4338
# Current email is 361/5728 and the                length of vocab is curr 4345
# Current email is 362/5728 and the                length of vocab is curr 4345
# Current email is 363/5728 and the                length of vocab is curr 4345
# Current email is 364/5728 and the                length of vocab is curr 4345
# Current email is 365/5728 and the                length of vocab is curr 4346
# Current email is 366/5728 and the                length of vocab is curr 4346
# Current email is 367/5728 and the                length of vocab is curr 4348
# Current email is 368/5728 and the                length of vocab is curr 4352
# Current email is 369/5728 and the                length of vocab is curr 4353
# Current email is 370/5728 and the                length of vocab is curr 4361
# Current email is 371/5728 and the                length of vocab is curr 4375
# Current email is 372/5728 and the                length of vocab is curr 4375
# Current email is 373/5728 and the                length of vocab is curr 4375
# Current email is 374/5728 and the                length of vocab is curr 4382
# Current email is 375/5728 and the                length of vocab is curr 4382
# Current email is 376/5728 and the                length of vocab is curr 4382
# Current email is 377/5728 and the                length of vocab is curr 4382
# Current email is 378/5728 and the                length of vocab is curr 4395
# Current email is 379/5728 and the                length of vocab is curr 4395
# Current email is 380/5728 and the                length of vocab is curr 4395
# Current email is 381/5728 and the                length of vocab is curr 4406
# Current email is 382/5728 and the                length of vocab is curr 4411
# Current email is 383/5728 and the                length of vocab is curr 4411
# Current email is 384/5728 and the                length of vocab is curr 4412
# Current email is 385/5728 and the                length of vocab is curr 4412
# Current email is 386/5728 and the                length of vocab is curr 4412
# Current email is 387/5728 and the                length of vocab is curr 4426
# Current email is 388/5728 and the                length of vocab is curr 4441
# Current email is 389/5728 and the                length of vocab is curr 4442
# Current email is 390/5728 and the                length of vocab is curr 4469
# Current email is 391/5728 and the                length of vocab is curr 4471
# Current email is 392/5728 and the                length of vocab is curr 4471
# Current email is 393/5728 and the                length of vocab is curr 4474
# Current email is 394/5728 and the                length of vocab is curr 4491
# Current email is 395/5728 and the                length of vocab is curr 4496
# Current email is 396/5728 and the                length of vocab is curr 4500
# Current email is 397/5728 and the                length of vocab is curr 4505
# Current email is 398/5728 and the                length of vocab is curr 4505
# Current email is 399/5728 and the                length of vocab is curr 4507
# Current email is 400/5728 and the                length of vocab is curr 4518
# Current email is 401/5728 and the                length of vocab is curr 4525
# Current email is 402/5728 and the                length of vocab is curr 4534
# Current email is 403/5728 and the                length of vocab is curr 4534
# Current email is 404/5728 and the                length of vocab is curr 4552
# Current email is 405/5728 and the                length of vocab is curr 4555
# Current email is 406/5728 and the                length of vocab is curr 4555
# Current email is 407/5728 and the                length of vocab is curr 4558
# Current email is 408/5728 and the                length of vocab is curr 4558
# Current email is 409/5728 and the                length of vocab is curr 4560
# Current email is 410/5728 and the                length of vocab is curr 4564
# Current email is 411/5728 and the                length of vocab is curr 4564
# Current email is 412/5728 and the                length of vocab is curr 4564
# Current email is 413/5728 and the                length of vocab is curr 4575
# Current email is 414/5728 and the                length of vocab is curr 4575
# Current email is 415/5728 and the                length of vocab is curr 4576
# Current email is 416/5728 and the                length of vocab is curr 4576
# Current email is 417/5728 and the                length of vocab is curr 4577
# Current email is 418/5728 and the                length of vocab is curr 4580
# Current email is 419/5728 and the                length of vocab is curr 4596
# Current email is 420/5728 and the                length of vocab is curr 4599
# Current email is 421/5728 and the                length of vocab is curr 4610
# Current email is 422/5728 and the                length of vocab is curr 4611
# Current email is 423/5728 and the                length of vocab is curr 4655
# Current email is 424/5728 and the                length of vocab is curr 4666
# Current email is 425/5728 and the                length of vocab is curr 4668
# Current email is 426/5728 and the                length of vocab is curr 4668
# Current email is 427/5728 and the                length of vocab is curr 4669
# Current email is 428/5728 and the                length of vocab is curr 4669
# Current email is 429/5728 and the                length of vocab is curr 4672
# Current email is 430/5728 and the                length of vocab is curr 4672
# Current email is 431/5728 and the                length of vocab is curr 4672
# Current email is 432/5728 and the                length of vocab is curr 4673
# Current email is 433/5728 and the                length of vocab is curr 4691
# Current email is 434/5728 and the                length of vocab is curr 4694
# Current email is 435/5728 and the                length of vocab is curr 4695
# Current email is 436/5728 and the                length of vocab is curr 4708
# Current email is 437/5728 and the                length of vocab is curr 4712
# Current email is 438/5728 and the                length of vocab is curr 4728
# Current email is 439/5728 and the                length of vocab is curr 4728
# Current email is 440/5728 and the                length of vocab is curr 4728
# Current email is 441/5728 and the                length of vocab is curr 4739
# Current email is 442/5728 and the                length of vocab is curr 4739
# Current email is 443/5728 and the                length of vocab is curr 4739
# Current email is 444/5728 and the                length of vocab is curr 4739
# Current email is 445/5728 and the                length of vocab is curr 4739
# Current email is 446/5728 and the                length of vocab is curr 4740
# Current email is 447/5728 and the                length of vocab is curr 4744
# Current email is 448/5728 and the                length of vocab is curr 4746
# Current email is 449/5728 and the                length of vocab is curr 4748
# Current email is 450/5728 and the                length of vocab is curr 4748
# Current email is 451/5728 and the                length of vocab is curr 4749
# Current email is 452/5728 and the                length of vocab is curr 4749
# Current email is 453/5728 and the                length of vocab is curr 4763
# Current email is 454/5728 and the                length of vocab is curr 4780
# Current email is 455/5728 and the                length of vocab is curr 4780
# Current email is 456/5728 and the                length of vocab is curr 4780
# Current email is 457/5728 and the                length of vocab is curr 4783
# Current email is 458/5728 and the                length of vocab is curr 4786
# Current email is 459/5728 and the                length of vocab is curr 4786
# Current email is 460/5728 and the                length of vocab is curr 4786
# Current email is 461/5728 and the                length of vocab is curr 4801
# Current email is 462/5728 and the                length of vocab is curr 4880
# Current email is 463/5728 and the                length of vocab is curr 4889
# Current email is 464/5728 and the                length of vocab is curr 4889
# Current email is 465/5728 and the                length of vocab is curr 4899
# Current email is 466/5728 and the                length of vocab is curr 4899
# Current email is 467/5728 and the                length of vocab is curr 4899
# Current email is 468/5728 and the                length of vocab is curr 4899
# Current email is 469/5728 and the                length of vocab is curr 4911
# Current email is 470/5728 and the                length of vocab is curr 4913
# Current email is 471/5728 and the                length of vocab is curr 4920
# Current email is 472/5728 and the                length of vocab is curr 4922
# Current email is 473/5728 and the                length of vocab is curr 4937
# Current email is 474/5728 and the                length of vocab is curr 4937
# Current email is 475/5728 and the                length of vocab is curr 4937
# Current email is 476/5728 and the                length of vocab is curr 4947
# Current email is 477/5728 and the                length of vocab is curr 4952
# Current email is 478/5728 and the                length of vocab is curr 4952
# Current email is 479/5728 and the                length of vocab is curr 4952
# Current email is 480/5728 and the                length of vocab is curr 4966
# Current email is 481/5728 and the                length of vocab is curr 4969
# Current email is 482/5728 and the                length of vocab is curr 4975
# Current email is 483/5728 and the                length of vocab is curr 4979
# Current email is 484/5728 and the                length of vocab is curr 4979
# Current email is 485/5728 and the                length of vocab is curr 4979
# Current email is 486/5728 and the                length of vocab is curr 4980
# Current email is 487/5728 and the                length of vocab is curr 4982
# Current email is 488/5728 and the                length of vocab is curr 4997
# Current email is 489/5728 and the                length of vocab is curr 5014
# Current email is 490/5728 and the                length of vocab is curr 5063
# Current email is 491/5728 and the                length of vocab is curr 5063
# Current email is 492/5728 and the                length of vocab is curr 5063
# Current email is 493/5728 and the                length of vocab is curr 5063
# Current email is 494/5728 and the                length of vocab is curr 5071
# Current email is 495/5728 and the                length of vocab is curr 5089
# Current email is 496/5728 and the                length of vocab is curr 5089
# Current email is 497/5728 and the                length of vocab is curr 5089
# Current email is 498/5728 and the                length of vocab is curr 5089
# Current email is 499/5728 and the                length of vocab is curr 5089
# Current email is 500/5728 and the                length of vocab is curr 5099
# Current email is 501/5728 and the                length of vocab is curr 5099
# Current email is 502/5728 and the                length of vocab is curr 5099
# Current email is 503/5728 and the                length of vocab is curr 5099
# Current email is 504/5728 and the                length of vocab is curr 5099
# Current email is 505/5728 and the                length of vocab is curr 5102
# Current email is 506/5728 and the                length of vocab is curr 5116
# Current email is 507/5728 and the                length of vocab is curr 5123
# Current email is 508/5728 and the                length of vocab is curr 5123
# Current email is 509/5728 and the                length of vocab is curr 5135
# Current email is 510/5728 and the                length of vocab is curr 5137
# Current email is 511/5728 and the                length of vocab is curr 5153
# Current email is 512/5728 and the                length of vocab is curr 5162
# Current email is 513/5728 and the                length of vocab is curr 5165
# Current email is 514/5728 and the                length of vocab is curr 5169
# Current email is 515/5728 and the                length of vocab is curr 5170
# Current email is 516/5728 and the                length of vocab is curr 5170
# Current email is 517/5728 and the                length of vocab is curr 5174
# Current email is 518/5728 and the                length of vocab is curr 5177
# Current email is 519/5728 and the                length of vocab is curr 5177
# Current email is 520/5728 and the                length of vocab is curr 5177
# Current email is 521/5728 and the                length of vocab is curr 5184
# Current email is 522/5728 and the                length of vocab is curr 5184
# Current email is 523/5728 and the                length of vocab is curr 5184
# Current email is 524/5728 and the                length of vocab is curr 5185
# Current email is 525/5728 and the                length of vocab is curr 5188
# Current email is 526/5728 and the                length of vocab is curr 5188
# Current email is 527/5728 and the                length of vocab is curr 5202
# Current email is 528/5728 and the                length of vocab is curr 5207
# Current email is 529/5728 and the                length of vocab is curr 5207
# Current email is 530/5728 and the                length of vocab is curr 5225
# Current email is 531/5728 and the                length of vocab is curr 5225
# Current email is 532/5728 and the                length of vocab is curr 5225
# Current email is 533/5728 and the                length of vocab is curr 5225
# Current email is 534/5728 and the                length of vocab is curr 5238
# Current email is 535/5728 and the                length of vocab is curr 5245
# Current email is 536/5728 and the                length of vocab is curr 5250
# Current email is 537/5728 and the                length of vocab is curr 5303
# Current email is 538/5728 and the                length of vocab is curr 5313
# Current email is 539/5728 and the                length of vocab is curr 5318
# Current email is 540/5728 and the                length of vocab is curr 5318
# Current email is 541/5728 and the                length of vocab is curr 5318
# Current email is 542/5728 and the                length of vocab is curr 5319
# Current email is 543/5728 and the                length of vocab is curr 5321
# Current email is 544/5728 and the                length of vocab is curr 5322
# Current email is 545/5728 and the                length of vocab is curr 5329
# Current email is 546/5728 and the                length of vocab is curr 5340
# Current email is 547/5728 and the                length of vocab is curr 5340
# Current email is 548/5728 and the                length of vocab is curr 5340
# Current email is 549/5728 and the                length of vocab is curr 5340
# Current email is 550/5728 and the                length of vocab is curr 5344
# Current email is 551/5728 and the                length of vocab is curr 5361
# Current email is 552/5728 and the                length of vocab is curr 5361
# Current email is 553/5728 and the                length of vocab is curr 5361
# Current email is 554/5728 and the                length of vocab is curr 5362
# Current email is 555/5728 and the                length of vocab is curr 5362
# Current email is 556/5728 and the                length of vocab is curr 5365
# Current email is 557/5728 and the                length of vocab is curr 5366
# Current email is 558/5728 and the                length of vocab is curr 5394
# Current email is 559/5728 and the                length of vocab is curr 5404
# Current email is 560/5728 and the                length of vocab is curr 5431
# Current email is 561/5728 and the                length of vocab is curr 5431
# Current email is 562/5728 and the                length of vocab is curr 5431
# Current email is 563/5728 and the                length of vocab is curr 5434
# Current email is 564/5728 and the                length of vocab is curr 5445
# Current email is 565/5728 and the                length of vocab is curr 5448
# Current email is 566/5728 and the                length of vocab is curr 5451
# Current email is 567/5728 and the                length of vocab is curr 5455
# Current email is 568/5728 and the                length of vocab is curr 5455
# Current email is 569/5728 and the                length of vocab is curr 5455
# Current email is 570/5728 and the                length of vocab is curr 5455
# Current email is 571/5728 and the                length of vocab is curr 5462
# Current email is 572/5728 and the                length of vocab is curr 5462
# Current email is 573/5728 and the                length of vocab is curr 5477
# Current email is 574/5728 and the                length of vocab is curr 5479
# Current email is 575/5728 and the                length of vocab is curr 5480
# Current email is 576/5728 and the                length of vocab is curr 5492
# Current email is 577/5728 and the                length of vocab is curr 5495
# Current email is 578/5728 and the                length of vocab is curr 5497
# Current email is 579/5728 and the                length of vocab is curr 5498
# Current email is 580/5728 and the                length of vocab is curr 5499
# Current email is 581/5728 and the                length of vocab is curr 5499
# Current email is 582/5728 and the                length of vocab is curr 5515
# Current email is 583/5728 and the                length of vocab is curr 5515
# Current email is 584/5728 and the                length of vocab is curr 5515
# Current email is 585/5728 and the                length of vocab is curr 5519
# Current email is 586/5728 and the                length of vocab is curr 5520
# Current email is 587/5728 and the                length of vocab is curr 5520
# Current email is 588/5728 and the                length of vocab is curr 5529
# Current email is 589/5728 and the                length of vocab is curr 5530
# Current email is 590/5728 and the                length of vocab is curr 5530
# Current email is 591/5728 and the                length of vocab is curr 5530
# Current email is 592/5728 and the                length of vocab is curr 5532
# Current email is 593/5728 and the                length of vocab is curr 5538
# Current email is 594/5728 and the                length of vocab is curr 5551
# Current email is 595/5728 and the                length of vocab is curr 5551
# Current email is 596/5728 and the                length of vocab is curr 5551
# Current email is 597/5728 and the                length of vocab is curr 5554
# Current email is 598/5728 and the                length of vocab is curr 5556
# Current email is 599/5728 and the                length of vocab is curr 5556
# Current email is 600/5728 and the                length of vocab is curr 5556
# Current email is 601/5728 and the                length of vocab is curr 5570
# Current email is 602/5728 and the                length of vocab is curr 5570
# Current email is 603/5728 and the                length of vocab is curr 5570
# Current email is 604/5728 and the                length of vocab is curr 5574
# Current email is 605/5728 and the                length of vocab is curr 5589
# Current email is 606/5728 and the                length of vocab is curr 5590
# Current email is 607/5728 and the                length of vocab is curr 5591
# Current email is 608/5728 and the                length of vocab is curr 5592
# Current email is 609/5728 and the                length of vocab is curr 5594
# Current email is 610/5728 and the                length of vocab is curr 5594
# Current email is 611/5728 and the                length of vocab is curr 5594
# Current email is 612/5728 and the                length of vocab is curr 5594
# Current email is 613/5728 and the                length of vocab is curr 5594
# Current email is 614/5728 and the                length of vocab is curr 5601
# ...
# Current email is 5528/5728 and the                length of vocab is curr 11964
# Current email is 5529/5728 and the                length of vocab is curr 11964
# Current email is 5530/5728 and the                length of vocab is curr 11964
# Current email is 5531/5728 and the                length of vocab is curr 11964
# Current email is 5532/5728 and the                length of vocab is curr 11964
# Current email is 5533/5728 and the                length of vocab is curr 11964
# Current email is 5534/5728 and the                length of vocab is curr 11964
# Current email is 5535/5728 and the                length of vocab is curr 11964
# Current email is 5536/5728 and the                length of vocab is curr 11964
# Current email is 5537/5728 and the                length of vocab is curr 11964
# Current email is 5538/5728 and the                length of vocab is curr 11964
# Current email is 5539/5728 and the                length of vocab is curr 11964
# Current email is 5540/5728 and the                length of vocab is curr 11964
# Current email is 5541/5728 and the                length of vocab is curr 11964
# Current email is 5542/5728 and the                length of vocab is curr 11964
# Current email is 5543/5728 and the                length of vocab is curr 11964
# Current email is 5544/5728 and the                length of vocab is curr 11964
# Current email is 5545/5728 and the                length of vocab is curr 11964
# Current email is 5546/5728 and the                length of vocab is curr 11964
# Current email is 5547/5728 and the                length of vocab is curr 11964
# Current email is 5548/5728 and the                length of vocab is curr 11966
# Current email is 5549/5728 and the                length of vocab is curr 11966
# Current email is 5550/5728 and the                length of vocab is curr 11967
# Current email is 5551/5728 and the                length of vocab is curr 11967
# Current email is 5552/5728 and the                length of vocab is curr 11967
# Current email is 5553/5728 and the                length of vocab is curr 11967
# Current email is 5554/5728 and the                length of vocab is curr 11967
# Current email is 5555/5728 and the                length of vocab is curr 11969
# Current email is 5556/5728 and the                length of vocab is curr 11969
# Current email is 5557/5728 and the                length of vocab is curr 11969
# Current email is 5558/5728 and the                length of vocab is curr 11969
# Current email is 5559/5728 and the                length of vocab is curr 11969
# Current email is 5560/5728 and the                length of vocab is curr 11969
# Current email is 5561/5728 and the                length of vocab is curr 11969
# Current email is 5562/5728 and the                length of vocab is curr 11969
# Current email is 5563/5728 and the                length of vocab is curr 11969
# Current email is 5564/5728 and the                length of vocab is curr 11969
# Current email is 5565/5728 and the                length of vocab is curr 11969
# Current email is 5566/5728 and the                length of vocab is curr 11971
# Current email is 5567/5728 and the                length of vocab is curr 11971
# Current email is 5568/5728 and the                length of vocab is curr 11971
# Current email is 5569/5728 and the                length of vocab is curr 11971
# Current email is 5570/5728 and the                length of vocab is curr 11971
# Current email is 5571/5728 and the                length of vocab is curr 11971
# Current email is 5572/5728 and the                length of vocab is curr 11971
# Current email is 5573/5728 and the                length of vocab is curr 11971
# Current email is 5574/5728 and the                length of vocab is curr 11971
# Current email is 5575/5728 and the                length of vocab is curr 11971
# Current email is 5576/5728 and the                length of vocab is curr 11972
# Current email is 5577/5728 and the                length of vocab is curr 11972
# Current email is 5578/5728 and the                length of vocab is curr 11972
# Current email is 5579/5728 and the                length of vocab is curr 11972
# Current email is 5580/5728 and the                length of vocab is curr 11972
# Current email is 5581/5728 and the                length of vocab is curr 11972
# Current email is 5582/5728 and the                length of vocab is curr 11973
# Current email is 5583/5728 and the                length of vocab is curr 11974
# Current email is 5584/5728 and the                length of vocab is curr 11974
# Current email is 5585/5728 and the                length of vocab is curr 11974
# Current email is 5586/5728 and the                length of vocab is curr 11974
# Current email is 5587/5728 and the                length of vocab is curr 11975
# Current email is 5588/5728 and the                length of vocab is curr 11975
# Current email is 5589/5728 and the                length of vocab is curr 11975
# Current email is 5590/5728 and the                length of vocab is curr 11975
# Current email is 5591/5728 and the                length of vocab is curr 11975
# Current email is 5592/5728 and the                length of vocab is curr 11975
# Current email is 5593/5728 and the                length of vocab is curr 11976
# Current email is 5594/5728 and the                length of vocab is curr 11976
# Current email is 5595/5728 and the                length of vocab is curr 11976
# Current email is 5596/5728 and the                length of vocab is curr 11976
# Current email is 5597/5728 and the                length of vocab is curr 11976
# Current email is 5598/5728 and the                length of vocab is curr 11976
# Current email is 5599/5728 and the                length of vocab is curr 11976
# Current email is 5600/5728 and the                length of vocab is curr 11976
# Current email is 5601/5728 and the                length of vocab is curr 11979
# Current email is 5602/5728 and the                length of vocab is curr 11979
# Current email is 5603/5728 and the                length of vocab is curr 11979
# Current email is 5604/5728 and the                length of vocab is curr 11979
# Current email is 5605/5728 and the                length of vocab is curr 11979
# Current email is 5606/5728 and the                length of vocab is curr 11981
# Current email is 5607/5728 and the                length of vocab is curr 11981
# Current email is 5608/5728 and the                length of vocab is curr 11981
# Current email is 5609/5728 and the                length of vocab is curr 11981
# Current email is 5610/5728 and the                length of vocab is curr 11981
# Current email is 5611/5728 and the                length of vocab is curr 11981
# Current email is 5612/5728 and the                length of vocab is curr 11983
# Current email is 5613/5728 and the                length of vocab is curr 11983
# Current email is 5614/5728 and the                length of vocab is curr 11985
# Current email is 5615/5728 and the                length of vocab is curr 11985
# Current email is 5616/5728 and the                length of vocab is curr 11985
# Current email is 5617/5728 and the                length of vocab is curr 11985
# Current email is 5618/5728 and the                length of vocab is curr 11985
# Current email is 5619/5728 and the                length of vocab is curr 11986
# Current email is 5620/5728 and the                length of vocab is curr 11986
# Current email is 5621/5728 and the                length of vocab is curr 11986
# Current email is 5622/5728 and the                length of vocab is curr 11987
# Current email is 5623/5728 and the                length of vocab is curr 11987
# Current email is 5624/5728 and the                length of vocab is curr 11987
# Current email is 5625/5728 and the                length of vocab is curr 11988
# Current email is 5626/5728 and the                length of vocab is curr 11988
# Current email is 5627/5728 and the                length of vocab is curr 11988
# Current email is 5628/5728 and the                length of vocab is curr 11989
# Current email is 5629/5728 and the                length of vocab is curr 11989
# Current email is 5630/5728 and the                length of vocab is curr 11989
# Current email is 5631/5728 and the                length of vocab is curr 11989
# Current email is 5632/5728 and the                length of vocab is curr 11989
# Current email is 5633/5728 and the                length of vocab is curr 11989
# Current email is 5634/5728 and the                length of vocab is curr 11989
# Current email is 5635/5728 and the                length of vocab is curr 11989
# Current email is 5636/5728 and the                length of vocab is curr 11989
# Current email is 5637/5728 and the                length of vocab is curr 11992
# Current email is 5638/5728 and the                length of vocab is curr 11992
# Current email is 5639/5728 and the                length of vocab is curr 11992
# Current email is 5640/5728 and the                length of vocab is curr 11993
# Current email is 5641/5728 and the                length of vocab is curr 11993
# Current email is 5642/5728 and the                length of vocab is curr 11993
# Current email is 5643/5728 and the                length of vocab is curr 11993
# Current email is 5644/5728 and the                length of vocab is curr 11993
# Current email is 5645/5728 and the                length of vocab is curr 11999
# Current email is 5646/5728 and the                length of vocab is curr 11999
# Current email is 5647/5728 and the                length of vocab is curr 11999
# Current email is 5648/5728 and the                length of vocab is curr 11999
# Current email is 5649/5728 and the                length of vocab is curr 11999
# Current email is 5650/5728 and the                length of vocab is curr 11999
# Current email is 5651/5728 and the                length of vocab is curr 11999
# Current email is 5652/5728 and the                length of vocab is curr 11999
# Current email is 5653/5728 and the                length of vocab is curr 11999
# Current email is 5654/5728 and the                length of vocab is curr 11999
# Current email is 5655/5728 and the                length of vocab is curr 11999
# Current email is 5656/5728 and the                length of vocab is curr 11999
# Current email is 5657/5728 and the                length of vocab is curr 11999
# Current email is 5658/5728 and the                length of vocab is curr 11999
# Current email is 5659/5728 and the                length of vocab is curr 11999
# Current email is 5660/5728 and the                length of vocab is curr 11999
# Current email is 5661/5728 and the                length of vocab is curr 11999
# Current email is 5662/5728 and the                length of vocab is curr 11999
# Current email is 5663/5728 and the                length of vocab is curr 11999
# Current email is 5664/5728 and the                length of vocab is curr 11999
# Current email is 5665/5728 and the                length of vocab is curr 11999
# Current email is 5666/5728 and the                length of vocab is curr 11999
# Current email is 5667/5728 and the                length of vocab is curr 11999
# Current email is 5668/5728 and the                length of vocab is curr 11999
# Current email is 5669/5728 and the                length of vocab is curr 12000
# Current email is 5670/5728 and the                length of vocab is curr 12000
# Current email is 5671/5728 and the                length of vocab is curr 12000
# Current email is 5672/5728 and the                length of vocab is curr 12000
# Current email is 5673/5728 and the                length of vocab is curr 12000
# Current email is 5674/5728 and the                length of vocab is curr 12000
# Current email is 5675/5728 and the                length of vocab is curr 12000
# Current email is 5676/5728 and the                length of vocab is curr 12001
# Current email is 5677/5728 and the                length of vocab is curr 12001
# Current email is 5678/5728 and the                length of vocab is curr 12001
# Current email is 5679/5728 and the                length of vocab is curr 12001
# Current email is 5680/5728 and the                length of vocab is curr 12001
# Current email is 5681/5728 and the                length of vocab is curr 12001
# Current email is 5682/5728 and the                length of vocab is curr 12001
# Current email is 5683/5728 and the                length of vocab is curr 12001
# Current email is 5684/5728 and the                length of vocab is curr 12001
# Current email is 5685/5728 and the                length of vocab is curr 12001
# Current email is 5686/5728 and the                length of vocab is curr 12001
# Current email is 5687/5728 and the                length of vocab is curr 12001
# Current email is 5688/5728 and the                length of vocab is curr 12001
# Current email is 5689/5728 and the                length of vocab is curr 12001
# Current email is 5690/5728 and the                length of vocab is curr 12001
# Current email is 5691/5728 and the                length of vocab is curr 12001
# Current email is 5692/5728 and the                length of vocab is curr 12001
# Current email is 5693/5728 and the                length of vocab is curr 12001
# Current email is 5694/5728 and the                length of vocab is curr 12001
# Current email is 5695/5728 and the                length of vocab is curr 12001
# Current email is 5696/5728 and the                length of vocab is curr 12001
# Current email is 5697/5728 and the                length of vocab is curr 12001
# Current email is 5698/5728 and the                length of vocab is curr 12001
# Current email is 5699/5728 and the                length of vocab is curr 12001
# Current email is 5700/5728 and the                length of vocab is curr 12001
# Current email is 5701/5728 and the                length of vocab is curr 12001
# Current email is 5702/5728 and the                length of vocab is curr 12002
# Current email is 5703/5728 and the                length of vocab is curr 12002
# Current email is 5704/5728 and the                length of vocab is curr 12002
# Current email is 5705/5728 and the                length of vocab is curr 12002
# Current email is 5706/5728 and the                length of vocab is curr 12002
# Current email is 5707/5728 and the                length of vocab is curr 12002
# Current email is 5708/5728 and the                length of vocab is curr 12002
# Current email is 5709/5728 and the                length of vocab is curr 12003
# Current email is 5710/5728 and the                length of vocab is curr 12003
# Current email is 5711/5728 and the                length of vocab is curr 12003
# Current email is 5712/5728 and the                length of vocab is curr 12004
# Current email is 5713/5728 and the                length of vocab is curr 12004
# Current email is 5714/5728 and the                length of vocab is curr 12004
# Current email is 5715/5728 and the                length of vocab is curr 12004
# Current email is 5716/5728 and the                length of vocab is curr 12004
# Current email is 5717/5728 and the                length of vocab is curr 12004
# Current email is 5718/5728 and the                length of vocab is curr 12005
# Current email is 5719/5728 and the                length of vocab is curr 12005
# Current email is 5720/5728 and the                length of vocab is curr 12007
# Current email is 5721/5728 and the                length of vocab is curr 12007
# Current email is 5722/5728 and the                length of vocab is curr 12007
# Current email is 5723/5728 and the                length of vocab is curr 12007
# Current email is 5724/5728 and the                length of vocab is curr 12007
# Current email is 5725/5728 and the                length of vocab is curr 12007
# Current email is 5726/5728 and the                length of vocab is curr 12007
# Current email is 5727/5728 and the                length of vocab is curr 12008

# %%
data = pd.read_csv("data/emails.csv")
file = open("vocabulary.txt", "r")
contents = file.read()
vocabulary = ast.literal_eval(contents)

X = np.zeros((data.shape[0], len(vocabulary)))
y = np.zeros((data.shape[0]))

for i in range(data.shape[0]):
    email = data.iloc[i, :][0].split()

    for email_word in email:
        if email_word.lower() in vocabulary:
            X[i, vocabulary[email_word]] += 1

    y[i] = data.iloc[i, :][1]

# Save stored numpy arrays
np.save("data/X.npy", X)
np.save("data/y.npy", y)

# %%
class NaiveBayes:
    def __init__(self, X, y):
        self.num_examples, self.num_features = X.shape
        self.num_classes = len(np.unique(y))
        self.eps = 1e-6

    def fit(self, X):
        self.classes_mean = {}
        self.classes_variance = {}
        self.classes_prior = {}

        for c in range(self.num_classes):
            X_c = X[y == c]

            self.classes_mean[str(c)] = np.mean(X_c, axis=0)
            self.classes_variance[str(c)] = np.var(X_c, axis=0)
            self.classes_prior[str(c)] = X_c.shape[0] / X.shape[0]

    def predict(self, X):
        probs = np.zeros((self.num_examples, self.num_classes))

        for c in range(self.num_classes):
            prior = self.classes_prior[str(c)]
            probs_c = self.density_function(
                X, self.classes_mean[str(c)], self.classes_variance[str(c)]
            )
            probs[:, c] = probs_c + np.log(prior)

        return np.argmax(probs, 1)

    def density_function(self, x, mean, sigma):
        # Calculate probability from Gaussian density function
        const = -self.num_features / 2 * np.log(2 * np.pi) - 0.5 * np.sum(
            np.log(sigma + self.eps)
        )
        probs = 0.5 * np.sum(np.power(x - mean, 2) / (sigma + self.eps), 1)
        return const - probs


if __name__ == "__main__":
    # For spam emails (Make sure to run build_vocab etc. to have .npy files)
    X = np.load("data/X.npy")
    y = np.load("data/y.npy")

    NB = NaiveBayes(X, y)
    NB.fit(X)
    y_pred = NB.predict(X)

    print(f"Accuracy: {sum(y_pred==y)/X.shape[0]}")
# Out:
# Accuracy: 0.914804469273743
